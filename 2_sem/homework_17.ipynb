# %%
import numpy as np
import scipy.stats as sts
import scipy.optimize as opt
import scipy.integrate as quad
import sympy as sp
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import math
import random

# %% [markdown]
# ![image.png](attachment:6a06e551-9422-450b-978d-de685da5cc7d.png)

# %%
x = sts.uniform(0, 360 - 0)

# %%
x.cdf(80) - x.cdf(40)
# Out:
# 0.1111111111111111

# %%
x.mean()
# Out:
# 180.0

# %%
x.var()
# Out:
# 10800.0

# %% [markdown]
# ![image.png](attachment:e58673b4-e59d-4e8c-9966-ab355ffe219b.png)

# %%
x = sts.expon(0, 5)

# %%
x.cdf(30)
# Out:
# 0.9975212478233336

# %% [markdown]
# ![image.png](attachment:0dd08e2b-1a0d-4d5c-8351-15d5e258895f.png)

# %% [markdown]
# # Нет никакой информации об Y... Будем решать задачу в общем виде, предполагая, что X и Y - независимые велчины.

# %% [markdown]
# ![image.png](attachment:cd48c072-ba82-49f8-b187-14a404fba080.png)

# %% [markdown]
# ![image.png](attachment:fd730131-f401-4292-bce8-256d22d4ebb3.png)

# %%
x = sts.expon(0, 0.2)

# %%
x.sf(2)
# Out:
# 4.5399929762484854e-05

# %%
math.exp(1) ** - 10 # Ответы сошлись!
# Out:
# 4.5399929762484875e-05

# %% [markdown]
# ![image.png](attachment:8e3606de-957a-4fc4-95e1-4ed0352c8613.png)
