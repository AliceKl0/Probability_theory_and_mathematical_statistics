# %%
import numpy as np
import scipy.stats as sts
import sympy as sp
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ![image.png](attachment:91d955ec-4569-495b-9b19-fcc8b55ffeb3.png)

# %%
a = 0
sigma = 15
X = sts.norm(a, sigma)

1 - (X.sf(3) * 2) ** 4
# Out:
# 0.49860916311591885

# %% [markdown]
# ![image.png](attachment:07c6f58e-bd57-4193-8491-6f69cacb9dd8.png)

# %%
a = 5
sigma = 0.5
X = sts.norm(a, sigma)

X.cdf(7) - X.cdf(4)
# Out:
# 0.9772181968099877

# %% [markdown]
# ![image.png](attachment:428d7cc9-9651-4be0-902f-a0043b816230.png)

# %%
a = 172.5
sigma = 6
X = sts.norm(a, sigma)

X.cdf(170) - X.cdf(168)
# Out:
# 0.11183376713382143

# %% [markdown]
# ![image.png](attachment:cf21e8fc-544e-4269-89f4-665be8984ebd.png)

# %%
a = 20
sigma = 0.3
X = sts.norm(a, sigma)

X.cdf(19.5)
# Out:
# 0.0477903522728147

# %% [markdown]
# ![image.png](attachment:ced65597-a799-4073-8287-3fea779854ee.png)

# %%
a = 40.4
X0 = sts.norm(0, 1)

# %%
q = X0.ppf(0.18406)

# %%
sigma = sp.symbols('sigma')
sigma_2 = sp.solve([(35 - a) / sigma - q], [sigma])

# %%
Var_X = sigma_2[sigma]**2
Var_X
# Out:
# 35.9999623138261
