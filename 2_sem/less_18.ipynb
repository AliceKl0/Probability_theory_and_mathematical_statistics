# %%
import numpy as np
import scipy.stats as sts
import sympy as sp
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ![image.png](attachment:5ac7525b-178c-4f33-adb9-0f0f3dd2f287.png)

# %%
a = 173
sigma = 6
X = sts.norm(a, sigma)

# %%
X.cdf(182) - X.cdf(176)
# Out:
# 0.2417303374571288

# %%
X.cdf(176) - X.cdf(170)
# Out:
# 0.38292492254802624

# %%
X.ppf(0.7)
# Out:
# 176.14640307624825

# %%
X.isf(0.1)
# Out:
# 180.6893093932676

# %%
# Обратная
X.ppf(0.9)
# Out:
# 180.6893093932676
